# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/insurance-data.csv')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape 
#I have 1338 record
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.columns
#features
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.isna().sum()
# no nan values
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.duplicated()
#no duplication
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.countplot(data=df,x='sex',hue='smoker')
#no. fo male and female are nearly equal
#male smoker is larger

# %%
sns.kdeplot(data=df,x='age',y='charges')

# %%
sns.lineplot(data=df,x='age',y='charges')
#charge is directly prop with age

# %%
sns.catplot(data=df,y='charges',col='region')
#max charge in southwest

# %%
sns.lineplot(data=df,x='children',y='charges')
#charge is inverse proptional with children

# %%
sns.lineplot(data=df,x='smoker',y='charges')
#Q

# %%
sns.scatterplot(data=df,x='smoker',y='charges')
#smoker is larger

# %%
sns.scatterplot(data=df,x='sex',y='charges')

# %%
sns.boxplot(data=df,x='age')
#there is no outliers

# %%
sns.boxplot(data=df,x='charges')
#Q

# %%
sns.catplot(data=df,x='children',col='region',sharey=True,height=4, aspect=0.6, palette='rocket', kind='count',legend=True)
#Q  how to know max children

# %%
sns.catplot(data=df,y='children',col='region', kind='bar',legend=True)
#Q  how to know max children

# %%
sns.catplot(data=df,x='smoker',col='region',sharey=True,height=4, aspect=0.6, palette='rocket', kind='count',legend=True)
#max smoker in southeast

# %%
#sns.catplot(data=df,x='smoker',col='region',sharey=True,height=4, aspect=0.6, palette='rocket', kind='bar',legend=True)
#Q

# %%
#sns.catplot(data=df,x='bmi',col='region',sharey=True,height=4, aspect=0.6, palette='rocket', kind='count',legend=True)

"""region and bmi"""
# Out:
# 'region and bmi'

# %%
sns.scatterplot(data=df,x='bmi',y='smoker')

# %%
sns.scatterplot(data=df,x='bmi',y='charges',hue='smoker')
#smoker mostly paid
#smoker with high bmi

# %%
sns.heatmap(df.corr(),annot=True)

# %%
sns.scatterplot(data=df,x='age',y='children')

# %%
sns.lineplot(data=df,x='age',y='children')
#there is no relation

# %%
plt.pie(df['region'].value_counts(),data=df)
#Q
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2f41423b10>,
# ...
#  [Text(0.722119686055283, 0.8297850077046582, ''),
#   Text(-0.8627681631663758, 0.6823716704454532, ''),
#   Text(-0.7201694244483217, -0.8314782018127556, ''),
#   Text(0.7967551940047443, -0.7584069889092945, '')])

# %%
sns.countplot(x='region',data=df)
